# %% [markdown]
# <img src="https://dev.skillup.online/asset-v1:SkillUp+SKOAI101+PLU_2021_1+type@asset+block@SKO.png" width="250" align="center">
#
# <h1 align="center"><font size="5"> Analyzing and Visualizing Heart Failure Prediction Data</font></h1>

# %% [markdown]
# ## Importing Libraries

# %%
# import libraries
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# ## Reading Data Set

# %%
# Read the data set using read_csv function

df=pd.read_csv("Heart_Failure.xls")

# %% [markdown]
# ### Get glimpse of data

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  high_blood_pressure  \
# 0  75.0        0                       582         0                    1
# 1  55.0        0                      7861         0                    0
# 2  65.0        0                       146         0                    0
# 3  50.0        1                       111         0                    0
# 4  65.0        1                       160         1                    0
#
#    platelets  serum_creatinine  serum_sodium  sex/Week  smoking  DEATH_EVENT
# 0  265000.00               1.9           130         1        0            1
# 1  263358.03               1.1           136         1        0            1
# 2  162000.00               1.3           129         1        1            1
# 3  210000.00               1.9           137         1        0            1
# 4  327000.00               2.7           116         0        0            1

# %% [markdown]
# ### Q1. Create new dataframe <code>df_old</code> with <code>age>=60</code> and replace all the values in <code>age</code> column of <code>df_old</code> with <code>old age</code>

# %%
# Write your code here

df_old=df[df['age'] >=60]
#df_old['age']='old age'
#df_old.set_index('age', inplace=True)
df_old
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  high_blood_pressure  \
# 0    75.0        0                       582         0                    1
# 2    65.0        0                       146         0                    0
# 4    65.0        1                       160         1                    0
# 5    90.0        1                        47         0                    1
# 6    75.0        1                       246         0                    0
# ..    ...      ...                       ...       ...                  ...
# 288  65.0        0                       892         1                    0
# 289  90.0        1                       337         0                    0
# 291  60.0        0                       320         0                    0
# 293  63.0        1                       103         1                    0
# 294  62.0        0                        61         1                    1
#
#      platelets  serum_creatinine  serum_sodium  sex/Week  smoking  DEATH_EVENT
# 0    265000.00               1.9           130         1        0            1
# 2    162000.00               1.3           129         1        1            1
# 4    327000.00               2.7           116         0        0            1
# 5    204000.00               2.1           132         1        1            1
# 6    127000.00               1.2           137         1        0            1
# ..         ...               ...           ...       ...      ...          ...
# 288  263358.03               1.1           142         0        0            0
# 289  390000.00               0.9           144         0        0            0
# 291  133000.00               1.4           139         1        0            0
# 293  179000.00               0.9           136         1        1            0
# 294  155000.00               1.1           143         1        1            0
#
# [170 rows x 11 columns]

# %% [markdown]
# <details><summary>Click Here for the Hint</summary>
#
#
#
# ```
#     df_old=df[df['age'] >=60]
#     df_old['age']='old age'
#
#
#
# ```
#
#
#
# </details>

# %%
df_old_age=df_old.loc[:,['age']]
df_old_age['age']='old age'
df_old_age
# Out:
#          age
# 0    old age
# 2    old age
# 4    old age
# 5    old age
# 6    old age
# ..       ...
# 288  old age
# 289  old age
# 291  old age
# 293  old age
# 294  old age
#
# [170 rows x 1 columns]

# %%
df_old.loc[df.age  > 60, 'age'] = "oldage"
df_old.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5028\3165994678.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'oldage' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_old.loc[df.age  > 60, 'age'] = "oldage"
#       age  anaemia  creatinine_phosphokinase  diabetes  high_blood_pressure  \
# 0  oldage        0                       582         0                    1
# 2  oldage        0                       146         0                    0
# 4  oldage        1                       160         1                    0
# 5  oldage        1                        47         0                    1
# 6  oldage        1                       246         0                    0
#
#    platelets  serum_creatinine  serum_sodium  sex/Week  smoking  DEATH_EVENT
# 0   265000.0               1.9           130         1        0            1
# 2   162000.0               1.3           129         1        1            1
# 4   327000.0               2.7           116         0        0            1
# 5   204000.0               2.1           132         1        1            1
# 6   127000.0               1.2           137         1        0            1

# %% [markdown]
# ### Q2. Create new dataframe <code>df_middle_age</code> with <code>age</code>< 60 and replace all the values in <code>age</code> column of <code>df_middle_age</code> with <code>middle age</code>

# %%
# Write your code here
df_middle=df[df['age'] < 60]
#df_middle_age=df_middle.loc[:,['age']]
#df_middle.loc[:,'age']="middle age"
#df_middle_age['age']="middle age"
#df_middle[:,'age']=df_middle_age


df_middle.loc[df_middle['age'] < 60 ,'age'] = "middleage"
df_middle.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5028\23668435.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'middleage' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_middle.loc[df_middle['age'] < 60 ,'age'] = "middleage"
#           age  anaemia  creatinine_phosphokinase  diabetes  \
# 1   middleage        0                      7861         0
# 3   middleage        1                       111         0
# 12  middleage        1                       981         0
# 13  middleage        1                       168         0
# 14  middleage        1                        80         0
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex/Week  \
# 1                     0  263358.03               1.1           136         1
# 3                     0  210000.00               1.9           137         1
# 12                    0  136000.00               1.1           137         1
# 13                    1  276000.00               1.1           137         1
# 14                    1  427000.00               1.0           138         0
#
#     smoking  DEATH_EVENT
# 1         0            1
# 3         0            1
# 12        0            1
# 13        0            1
# 14        0            0

# %%
#OR

#df_middle=df[df['age'] < 60]
#df_middle_age=df_middle.loc[:,['age']]
#df_middle.loc[:,'age']="middle age"
#df_middle_age['age']="middle age"
#df_middle[:,'age']=df_middle_age

#mask = df[df['age'] < 60]
#column_name = 'age'
#df.loc[mask, [column_name]] = "midlleage"

# %% [markdown]
# ### Q3. Concatenate <code>df_old</code> and <code>df_middle_age</code> and form a new dataframe as <code>df_new</code>

# %%
# Hint: use pd.concat()
df_new=pd.concat([df_old, df_middle], ignore_index=True)
df_new
# Out:
#            age  anaemia  creatinine_phosphokinase  diabetes  \
# 0       oldage        0                       582         0
# 1       oldage        0                       146         0
# 2       oldage        1                       160         1
# 3       oldage        1                        47         0
# 4       oldage        1                       246         0
# ..         ...      ...                       ...       ...
# 294  middleage        0                       190         1
# 295  middleage        0                      1820         0
# 296  middleage        0                      2060         1
# 297  middleage        0                      2413         0
# 298  middleage        0                       196         0
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex/Week  \
# 0                      1   265000.0               1.9           130         1
# 1                      0   162000.0               1.3           129         1
# 2                      0   327000.0               2.7           116         0
# 3                      1   204000.0               2.1           132         1
# 4                      0   127000.0               1.2           137         1
# ..                   ...        ...               ...           ...       ...
# 294                    0   382000.0               1.0           140         1
# 295                    0   270000.0               1.2           139         0
# 296                    0   742000.0               0.8           138         0
# 297                    0   140000.0               1.4           140         1
# 298                    0   395000.0               1.6           136         1
#
#      smoking  DEATH_EVENT
# 0          0            1
# 1          1            1
# 2          0            1
# 3          1            1
# 4          0            1
# ..       ...          ...
# 294        1            0
# 295        0            0
# 296        0            0
# 297        1            0
# 298        1            0
#
# [299 rows x 11 columns]

# %% [markdown]
# ### Q4. Visualize <code>diabetes, platelets, DEATH_EVENT</code> for <code>middle age</code> and <code>old age</code> people

# %%
# Hint: sns.barplot(x='',y='',data=)
sns.barplot(x='age',y='diabetes',data=df_new)
# Out:
# <AxesSubplot:xlabel='age', ylabel='diabetes'>

# %%
plt.bar(df['age'], df['diabetes'], label='diabetes')
plt.bar(df['age'], df[' platelets'], bottom=df['diabetes'], label='platelets')
plt.bar(df['age'], df['DEATH_EVENT'], bottom=df['diabetes']+df['platelets'], label='Death')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' platelets'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5028\3609449240.py in <module>
#       1 plt.bar(df['age'], df['diabetes'], label='diabetes')
# ----> 2 plt.bar(df['age'], df[' platelets'], bottom=df['diabetes'], label='platelets')
#       3 plt.bar(df['age'], df['DEATH_EVENT'], bottom=df['diabetes']+df['platelets'], label='Death')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ' platelets'

# %% [markdown]
# ### Q5. groupby dataframe by <code>age</code> and calculate mean

# %%
# Write your code here
grouped=df.groupby('age')
grouped.head()

mean_v= grouped.mean().reset_index()
mean_v.head(10)
# Out:
#     age   anaemia  creatinine_phosphokinase  diabetes  high_blood_pressure  \
# 0  40.0  0.285714                321.142857  0.285714             0.142857
# 1  41.0  0.000000                148.000000  0.000000             0.000000
# 2  42.0  0.285714                908.142857  0.285714             0.000000
# 3  43.0  1.000000                358.000000  0.000000             0.000000
# 4  44.0  0.000000                333.000000  1.000000             1.000000
# 5  45.0  0.210526               1239.000000  0.578947             0.263158
# 6  46.0  0.333333                392.666667  0.333333             0.666667
# 7  47.0  0.000000                582.000000  0.000000             0.000000
# 8  48.0  1.000000                356.500000  1.000000             0.500000
# 9  49.0  0.500000                477.500000  0.250000             0.750000
#
#        platelets  serum_creatinine  serum_sodium  sex/Week   smoking  \
# 0  262428.571429          0.942857    137.714286  0.714286  0.285714
# 1  374000.000000          0.800000    140.000000  1.000000  1.000000
# 2  244051.147143          1.468571    137.142857  0.714286  0.428571
# 3  237000.000000          1.300000    135.000000  0.000000  0.000000
# 4  249179.015000          1.150000    134.500000  1.000000  0.500000
# 5  331300.845263          1.024211    137.578947  0.631579  0.157895
# 6  294119.343333          1.393333    133.666667  0.000000  0.000000
# 7  130000.000000          0.800000    134.000000  1.000000  0.000000
# 8  165500.000000          1.750000    125.500000  0.000000  0.000000
# 9  286500.000000          0.975000    136.000000  0.250000  0.250000
#
#    DEATH_EVENT
# 0     0.000000
# 1     0.000000
# 2     0.142857
# 3     0.000000
# 4     0.000000
# 5     0.315789
# 6     0.333333
# 7     0.000000
# 8     1.000000
# 9     0.250000

# %% [markdown]
# <details><summary>Click Here for the Hint</summary>
#
#
#
# ```
#     df_avg=df_new.groupby(by='age').mean()
#     df_avg.reset_index(inplace=True)
#
#
#
# ```
#
#
#
# </details>

# %% [markdown]
# ### Q6. Visualize average <code>platelets</code> for <code>middle age</code> and <code>old age</code> people

# %%
# Write your code here
meanp=df.groupby('platelets')
meanpp=meanp.mean().reset_index()
sns.barplot(x='age',y='platelets',data=meanpp)
# Out:
# <AxesSubplot:xlabel='age', ylabel='platelets'>

# %% [markdown]
# ## Assignment Notebook Submission
#
# Once you complete your notebook you will have to share it. Save all your work and download the file. You will be submitting your notebook for peer review in the next section of the course.

# %% [markdown]
# ## Author(s)
#
# Aditya Singh
#
# ## Changelog
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 1.0 | Aditya | Created new version |
# |   |   |   |   |
